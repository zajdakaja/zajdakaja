# %% [markdown]
# # Testing openSMILE

# %%
import opensmile
from ..utils.audio_helpers import load_wav
audio_path = '../data/raw/sample_pl.wav'
y, sr = load_wav(audio_path)
smile = opensmile.Smile(feature_set=opensmile.FeatureSet.ComParE_2016)
features = smile.process_signal(y, sr)
features.head()
