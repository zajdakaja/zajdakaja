# %% [markdown]
# # Testing spaCy and NLTK

# %%
from ..utils.text_helpers import tokenize_text
text = open('../data/transcripts/sample_en.txt').read()
tokens = tokenize_text(text, lang='en')
tokens[:10]
