# %% [markdown]
# # Testing Praat Waveforms

# %%
import parselmouth
from ..utils.audio_helpers import load_wav
audio_path = '../data/raw/sample_en.wav'
snd = parselmouth.Sound(audio_path)
pitch = snd.to_pitch()
pitch.selected_array['frequency'][:10]
