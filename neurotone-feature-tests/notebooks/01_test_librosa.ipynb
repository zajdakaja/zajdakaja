# %% [markdown]
# # Testing Librosa

# %%
from ..utils.audio_helpers import load_wav, extract_mfcc
audio_path = '../data/raw/sample_en.wav'
y, sr = load_wav(audio_path)
mfcc = extract_mfcc(y, sr)
mfcc.shape
